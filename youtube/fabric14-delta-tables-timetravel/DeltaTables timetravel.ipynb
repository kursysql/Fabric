# %% [markdown]
# [![logo kursyFabric](http://www.kursysql.pl/kursySQLlogo_fabric_200px.png)](https://www.kursyfabric.pl)
#
# # Delta Tables - podróże w czasie
# - Dane testowe
# - DESCRIBE HISTORY - analiza historii
# - RESTORE (cofanie wersji) tabeli
#
# - [demo na YouTube](https://youtu.be/UpKbrBSCLgA)
# - [poozostałe filmy na kanale YT](https://www.youtube.com/watch?v=9FXwqwAcTYM&list=PLLbGIlLHMPz1hJpR84BWLpBSgRay10XD1)

# %% [markdown]
# ## Dane testowe

# %%
# %%sql
# -- utworzenie tabeli
# DROP TABLE IF EXISTS Products;
#
# CREATE TABLE Products (
#     ProductID int not null,
#     ProductName string not null,
#     SubcategoryName string not null,
#     CategoryName string not null,
#     ProductNumber string not null,
#     Color string not null,
#     SafetyStockLevel int not null,
#     ListPrice decimal
# );
#
# SELECT * FROM Products
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 33, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 8 fields>

# %%
# %%sql
#
# -- (1) wstawienie 6 wierszy
# INSERT INTO Products (ProductID, ProductName, SubcategoryName, CategoryName, ProductNumber, Color, SafetyStockLevel, ListPrice)
# VALUES (680, 'HL Road Frame - Black, 58', 'Road Frames', 'Components', 'FR-R92B-58', 'Black', 500, 1431.50),
#     (706, 'HL Road Frame - Red, 58', 'Road Frames', 'Components', 'FR-R92R-58' ,'Red', 500,	1431.50),
#     (707, 'Sport-100 Helmet, Red', 'Helmets', 'Accessories', 'HL-U509-R', 'Red', 4, 34.99),
#     (708, 'Sport-100 Helmet, Black', 'Helmets', 'Accessories', 'HL-U509', 'Black', 4, 34.99),
#     (711, 'Sport-100 Helmet, Blue', 'Helmets', 'Accessories', 'HL-U509-B', 'Blue', 4, 34.99),
#     (712, 'AWC Logo Cap', 'Caps', 'Clothing', 'CA-1098', 'Multi', 4, 8.99);
#
# -- (2) ... i jeszcze dwóch...
# INSERT INTO Products (ProductID, ProductName, SubcategoryName, CategoryName, ProductNumber, Color, SafetyStockLevel, ListPrice)
# VALUES (709, 'Mountain Bike Socks, M', 'Socks', 'Clothing', 'SO-B909-M', 'White', 4, 9.50),
#     (710, 'Mountain Bike Socks, L', 'Socks', 'Clothing', 'SO-B909-L', 'White', 4, 9.50);
#
# -- (3) skasowanie 2 wierszy...
# DELETE FROM Products WHERE SubcategoryName = 'Socks';
#
# -- (4) i ponowne wstawienie 2 wierszy
# INSERT INTO Products (ProductID, ProductName, SubcategoryName, CategoryName, ProductNumber, Color, SafetyStockLevel, ListPrice)
# VALUES (709, 'Mountain Bike Socks, M', 'Socks', 'Clothing', 'SO-B909-M', 'White', 4, 9.50),
#     (710, 'Mountain Bike Socks, L', 'Socks', 'Clothing', 'SO-B909-L', 'White', 4, 9.50);
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 37, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 1 rows and 1 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# -- sprawdzenie zawartości tabeli
# SELECT * FROM Products;
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 38, Finished, Available, Finished)
# <Spark SQL result set with 8 rows and 8 fields>

# %%
# %%sql
# -- (5) skasowanie wszystkich wierszy z tabeli
# DELETE FROM Products
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 39, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>

# %%
# %%sql
# -- sprawdzenie zawartości tabeli
# SELECT * FROM Products;
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 40, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 8 fields>

# %% [markdown]
# ## DESCRIBE HISTORY - analiza historii

# %%
# %%sql
# -- historia wersji i operacji tabeli
# DESCRIBE HISTORY Products
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 41, Finished, Available, Finished)
# <Spark SQL result set with 6 rows and 15 fields>

# %%
# %%sql
# -- sprawdzenie zawartości tabeli
# SELECT * FROM Products;
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 42, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 8 fields>

# %%
# %%sql
# -- sprawdzenie poprzedniej wersji (pierwsze wstawienie 6 wierszy)
# SELECT * FROM Products VERSION AS OF 1;
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 43, Finished, Available, Finished)
# <Spark SQL result set with 6 rows and 8 fields>

# %%
# %%sql
# -- sprawdzenie poprzedniej podając datę/godzinę - wskazują czas kiedy nie istniała tabela
# SELECT * FROM Products TIMESTAMP AS OF '2025-01-12T08:34:47';
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 46, Finished, Available, Finished)
# The provided timestamp: 2025-01-12 10:34:47.0 is after the latest commit timestamp of
# 2025-01-12 10:32:34.235. If you wish to query this version of the table, please either provide
# the version with "VERSION AS OF 5" or use the exact timestamp
# of the last commit: "TIMESTAMP AS OF '2025-01-12 10:32:34'".
#
# org.apache.spark.sql.delta.DeltaHistoryManager.getActiveCommitAtTime(DeltaHistoryManager.scala:311)
# org.apache.spark.sql.delta.DeltaTableUtils$.resolveTimeTravelVersion(DeltaTable.scala:486)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.$anonfun$initialSnapshot$2(DeltaTableV2.scala:134)
# scala.Option.map(Option.scala:230)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.$anonfun$initialSnapshot$1(DeltaTableV2.scala:127)
# org.apache.spark.sql.delta.catalog.DeltaTableV2$.withEnrichedUnsupportedTableException(DeltaTableV2.scala:367)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.initialSnapshot$lzycompute(DeltaTableV2.scala:144)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.initialSnapshot(DeltaTableV2.scala:124)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.$anonfun$tableSchema$2(DeltaTableV2.scala:168)
# scala.Option.getOrElse(Option.scala:189)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.tableSchema$lzycompute(DeltaTableV2.scala:168)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.tableSchema(DeltaTableV2.scala:166)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.schema(DeltaTableV2.scala:173)
# org.apache.spark.sql.connector.catalog.Table.columns(Table.java:65)
# org.apache.spark.sql.delta.catalog.DeltaTableV2.columns(DeltaTableV2.scala:58)
# org.apache.spark.sql.execution.datasources.v2.DataSourceV2Relation$.create(DataSourceV2Relation.scala:197)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.$anonfun$createRelation$1(Analyzer.scala:1325)
# scala.Option.map(Option.scala:230)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.createRelation(Analyzer.scala:1297)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.$anonfun$resolveRelation$3(Analyzer.scala:1356)
# scala.Option.orElse(Option.scala:447)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.$anonfun$resolveRelation$1(Analyzer.scala:1350)
# scala.Option.orElse(Option.scala:447)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.org$apache$spark$sql$catalyst$analysis$Analyzer$ResolveRelations$$resolveRelation(Analyzer.scala:1337)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$$anonfun$apply$14.applyOrElse(Analyzer.scala:1206)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$$anonfun$apply$14.applyOrElse(Analyzer.scala:1166)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$3(AnalysisHelper.scala:138)
# org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:76)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$1(AnalysisHelper.scala:138)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:323)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning(AnalysisHelper.scala:134)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning$(AnalysisHelper.scala:130)
# org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.resolveOperatorsUpWithPruning(LogicalPlan.scala:33)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$2(AnalysisHelper.scala:135)
# org.apache.spark.sql.catalyst.trees.UnaryLike.mapChildren(TreeNode.scala:1215)
# org.apache.spark.sql.catalyst.trees.UnaryLike.mapChildren$(TreeNode.scala:1214)
# org.apache.spark.sql.catalyst.plans.logical.Project.mapChildren(basicLogicalOperators.scala:71)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.$anonfun$resolveOperatorsUpWithPruning$1(AnalysisHelper.scala:135)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:323)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning(AnalysisHelper.scala:134)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.resolveOperatorsUpWithPruning$(AnalysisHelper.scala:130)
# org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.resolveOperatorsUpWithPruning(LogicalPlan.scala:33)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.apply(Analyzer.scala:1166)
# org.apache.spark.sql.catalyst.analysis.Analyzer$ResolveRelations$.apply(Analyzer.scala:1125)
# org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$2(RuleExecutor.scala:222)
# scala.collection.LinearSeqOptimized.foldLeft(LinearSeqOptimized.scala:126)
# scala.collection.LinearSeqOptimized.foldLeft$(LinearSeqOptimized.scala:122)
# scala.collection.immutable.List.foldLeft(List.scala:91)
# org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$1(RuleExecutor.scala:219)
# org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$execute$1$adapted(RuleExecutor.scala:211)
# scala.collection.immutable.List.foreach(List.scala:431)
# org.apache.spark.sql.catalyst.rules.RuleExecutor.execute(RuleExecutor.scala:211)
# org.apache.spark.sql.catalyst.analysis.Analyzer.org$apache$spark$sql$catalyst$analysis$Analyzer$$executeSameContext(Analyzer.scala:228)
# org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$execute$1(Analyzer.scala:224)
# org.apache.spark.sql.catalyst.analysis.AnalysisContext$.withNewAnalysisContext(Analyzer.scala:175)
# org.apache.spark.sql.catalyst.analysis.Analyzer.execute(Analyzer.scala:224)
# org.apache.spark.sql.catalyst.analysis.Analyzer.execute(Analyzer.scala:190)
# org.apache.spark.sql.catalyst.rules.RuleExecutor.$anonfun$executeAndTrack$1(RuleExecutor.scala:182)
# org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:94)
# org.apache.spark.sql.catalyst.rules.RuleExecutor.executeAndTrack(RuleExecutor.scala:182)
# org.apache.spark.sql.catalyst.analysis.Analyzer.$anonfun$executeAndCheck$1(Analyzer.scala:211)
# org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.markInAnalyzer(AnalysisHelper.scala:330)
# org.apache.spark.sql.catalyst.analysis.Analyzer.executeAndCheck(Analyzer.scala:210)
# org.apache.spark.sql.execution.QueryExecution.$anonfun$analyzed$1(QueryExecution.scala:120)
# org.apache.spark.sql.catalyst.QueryPlanningTracker.measurePhase(QueryPlanningTracker.scala:148)
# org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$2(QueryExecution.scala:304)
# org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:660)
# org.apache.spark.sql.execution.QueryExecution.$anonfun$executePhase$1(QueryExecution.scala:304)
# org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:900)
# org.apache.spark.sql.execution.QueryExecution.executePhase(QueryExecution.scala:303)
# org.apache.spark.sql.execution.QueryExecution.analyzed$lzycompute(QueryExecution.scala:120)
# org.apache.spark.sql.execution.QueryExecution.analyzed(QueryExecution.scala:117)
# org.apache.spark.sql.execution.QueryExecution.assertAnalyzed(QueryExecution.scala:109)
# org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:100)
# org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:900)
# org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:98)
# org.apache.spark.sql.SparkSession.$anonfun$sql$4(SparkSession.scala:691)
# org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:900)
# org.apache.spark.sql.SparkSession.sql(SparkSession.scala:682)
# org.apache.spark.sql.SparkSession.sql(SparkSession.scala:713)
# org.apache.spark.sql.SparkSession.sql(SparkSession.scala:744)
# org.apache.livy.repl.SQLInterpreter.execute(SQLInterpreter.scala:163)
# org.apache.livy.repl.Session.$anonfun$executeCode$1(Session.scala:893)
# scala.Option.map(Option.scala:230)
# org.apache.livy.repl.Session.executeCode(Session.scala:890)
# org.apache.livy.repl.Session.$anonfun$execute$12(Session.scala:585)
# org.apache.livy.repl.Session.withRealtimeOutputSupport(Session.scala:1144)
# org.apache.livy.repl.Session.$anonfun$execute$3(Session.scala:585)
# scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# scala.concurrent.Future$.$anonfun$apply$1(Future.scala:659)
# scala.util.Success.$anonfun$map$1(Try.scala:255)
# scala.util.Success.map(Try.scala:213)
# scala.concurrent.Future.$anonfun$map$1(Future.scala:292)
# scala.concurrent.impl.Promise.liftedTree1$1(Promise.scala:33)
# scala.concurrent.impl.Promise.$anonfun$transform$1(Promise.scala:33)
# scala.concurrent.impl.CallbackRunnable.run(Promise.scala:64)
# java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# java.base/java.lang.Thread.run(Thread.java:829)

# %%
# %%sql
# -- sprawdzenie poprzedniej podając datę/godzinę - po wykonaniu pierwszej komórki
# SELECT * FROM Products TIMESTAMP AS OF '2025-01-12 10:32:21';
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 52, Finished, Available, Finished)
# <Spark SQL result set with 8 rows and 8 fields>

# %% [markdown]
# ## RESTORE (cofanie wersji) tabeli

# %%
# %%sql
# -- jeszcze raz sprawdzenie aktualnej zawartości tabeli (pusta)
# SELECT * FROM Products
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 53, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 8 fields>

# %%
# %%sql
# -- jeszcze raz sprawdzenie historii
# DESCRIBE HISTORY Products
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 54, Finished, Available, Finished)
# <Spark SQL result set with 6 rows and 15 fields>

# %%
# %%sql
# -- wycofanie ostatniej operacji kasowania = przywrócenie wersji 4 - przed ostatnim DELETE
# RESTORE TABLE Products TO VERSION AS OF 4
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 55, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 6 fields>

# %%
# %%sql
# -- sprawdzenie czy w tabeli znowu jest 8 rekordów
# SELECT * FROM Products
# Out:
# StatementMeta(, 604c8946-70a4-4b6a-9a78-be546e52dfe0, 56, Finished, Available, Finished)
# <Spark SQL result set with 8 rows and 8 fields>
